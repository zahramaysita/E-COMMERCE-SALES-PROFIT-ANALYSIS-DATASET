# %% [markdown]
# # **E-COMMERCE SALES & PROFIT ANALYSIS DATASET**

# %% [markdown]
# # **IMPORT LIBRARY**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Business Understanding**

# %% [markdown]
# ## **Business Objective**

# %% [markdown]
# Analisis pada dataset transaksi e-commerce ini bertujuan untuk membantu manajemen dalam memahami dan mengevaluasi kinerja penjualan serta profitabilitas perusahaan berdasarkan data 3.500 transaksi yang tersedia. Fokus analisis mencakup identifikasi pola penjualan berdasarkan produk, kategori, dan wilayah, serta bagaimana jumlah pembelian mempengaruhi pendapatan (revenue) dan keuntungan (profit).
#
# Melalui pendekatan analitik data, perusahaan dapat mengetahui kategori atau wilayah mana yang memberikan kontribusi pendapatan tertinggi, produk mana yang memiliki margin keuntungan terbesar, serta mengidentifikasi kondisi di mana penjualan tinggi tidak sebanding dengan keuntungan yang diperoleh. Hasil analisis ini diharapkan dapat menjadi dasar dalam pengambilan keputusan strategis untuk meningkatkan efisiensi penjualan dan memaksimalkan keuntungan perusahaan.

# %% [markdown]
# ## **Assess Situation**

# %% [markdown]
# Situasi bisnis yang mendasari analisis ini adalah meningkatnya kompleksitas operasional perusahaan e-commerce yang menangani ribuan transaksi dari berbagai kategori produk dan wilayah pemasaran. Dengan total 3.500 transaksi yang tercatat, perusahaan menghadapi tantangan dalam memastikan bahwa peningkatan jumlah penjualan benar-benar sejalan dengan pertumbuhan keuntungan yang optimal. Volume transaksi yang besar serta variasi kategori produk dan wilayah menyebabkan manajemen kesulitan dalam memantau performa profitabilitas secara menyeluruh.
#
# Meskipun seluruh data transaksi telah terdokumentasi secara digital, masih terdapat potensi ketidakseimbangan antara pendapatan dan keuntungan pada beberapa kategori atau wilayah tertentu. Kondisi di mana penjualan tinggi tidak menghasilkan profit yang maksimal dapat mengindikasikan adanya permasalahan pada struktur biaya, strategi harga, atau efisiensi operasional. Tanpa analisis dan visualisasi data yang sistematis, manajemen akan kesulitan dalam mengidentifikasi pola performa penjualan, kontribusi tiap kategori, serta faktor-faktor yang mempengaruhi profitabilitas.
#
# Oleh karena itu, diperlukan proses analisis data yang komprehensif untuk mengevaluasi kondisi dataset, mengidentifikasi pola distribusi penjualan dan keuntungan, serta menemukan insight strategis yang dapat mendukung pengambilan keputusan bisnis dalam meningkatkan efektivitas penjualan dan memaksimalkan profit perusahaan.

# %% [markdown]
# ## **Analytic Goals**

# %% [markdown]
# Rencana proyek ini mencakup langkah-langkah terstruktur dari pengolahan data hingga penyajian hasil untuk mencapai tujuan bisnis yang telah ditetapkan:
#
# * Pengumpulan dan Eksplorasi Data (Data Understanding):
# Melakukan pemeriksaan struktur dataset yang terdiri dari 3.500 transaksi dan 7 fitur utama, termasuk pengecekan tipe data, missing values, duplicated values, inconsistent values, statistik deskriptif, serta identifikasi outliers untuk memahami karakteristik awal data.
#
# * Pembersihan Data (Data Preparation):
# Melakukan perbaikan terhadap data yang tidak konsisten, menghapus data duplikat, menangani nilai kosong, serta memastikan format data sudah sesuai untuk proses analisis lanjutan.
#
# * Analisis Data (Data Analysis):
# Melakukan eksplorasi data untuk mengidentifikasi pola penjualan, hubungan antara jumlah pembelian, pendapatan, dan keuntungan, serta menganalisis performa berdasarkan kategori produk dan wilayah.
#
# * Analisis Wilayah:
# Mengevaluasi performa penjualan dan profit pada berbagai wilayah pemasaran guna mengetahui wilayah dengan kontribusi pendapatan dan keuntungan tertinggi maupun terendah.
#
# * Visualisasi Data dan Reporting:
# Menyajikan hasil analisis dalam bentuk visualisasi yang informatif serta menyimpulkan temuan utama sebagai dasar rekomendasi strategis.

# %% [markdown]
# ## **Project Plan**

# %% [markdown]
# Tujuan utama dari analisis data ini adalah untuk menghasilkan wawasan yang dapat ditindaklanjuti guna meningkatkan performa bisnis e-commerce secara menyeluruh. Secara spesifik, tujuan yang ingin dicapai adalah:
#
# * Mengidentifikasi tren dan pola penjualan berdasarkan kategori dan wilayah
#
# * Menganalisis profitabilitas perusahaan berdasarkan revenue dan profit
#
# * Mengevaluasi kontribusi wilayah dan kategori terhadap total pendapatan dan keuntungan
#
# * Mengidentifikasi kondisi penjualan tinggi dengan profit rendah
#
# * Menghasilkan visualisasi data yang komunikatif dan akurat sebagai alat bantu manajemen
#
# * Menyediakan dasar pengambilan keputusan strategis berbasis data

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## **Memuat Dataset**

# %% [markdown]
# Sumber dataset ini berasal dari data transaksi e-commerce perusahaan yang terdiri dari 3.500 transaksi, yang bertujuan untuk mengevaluasi dan meningkatkan performa penjualan serta profitabilitas perusahaan berdasarkan kategori produk dan wilayah pemasaran.

# %%
path = "/content/drive/MyDrive/CheckPoint 1/ecommerce_sales_data (2).csv"
df = pd.read_csv(path)
df
# Out:
#       Order Date Product Name     Category Region  Quantity  Sales   Profit
# 0     2024-12-31      Printer       Office  North         4   3640   348.93
# 1     2022-11-27        Mouse  Accessories   East         7   1197   106.53
# 2     2022-05-11       Tablet  Electronics  South         5   5865   502.73
# 3     2024-03-16        Mouse  Accessories  South         2    786   202.87
# 4     2022-09-10        Mouse  Accessories   West         1    509   103.28
# ...          ...          ...          ...    ...       ...    ...      ...
# 3495  2023-02-15      Monitor  Accessories  North         4   4064   771.16
# 3496  2022-09-18      Monitor  Accessories   East         1   1117   119.89
# 3497  2022-04-12       Laptop  Electronics  South         4    260    66.02
# 3498  2022-01-18      Printer       Office  South         3    222    50.28
# 3499  2024-11-01   Smartwatch  Electronics   East         9  10530  1777.32
#
# [3500 rows x 7 columns]

# %% [markdown]
# ## **Deskripsi Data**

# %% [markdown]
# ### **Informasi Dasar**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order Date    3500 non-null   object
#  1   Product Name  3500 non-null   object
#  2   Category      3500 non-null   object
#  3   Region        3500 non-null   object
#  4   Quantity      3500 non-null   int64
#  5   Sales         3500 non-null   int64
#  6   Profit        3500 non-null   float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 191.5+ KB

# %% [markdown]
# Berdasarkan data di atas, dapat diketahui bahwa dataset ini memiliki 3500 Baris dan 7 Kolom

# %% [markdown]
# ### **Informasi Lanjutan**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order Date    3500 non-null   object
#  1   Product Name  3500 non-null   object
#  2   Category      3500 non-null   object
#  3   Region        3500 non-null   object
#  4   Quantity      3500 non-null   int64
#  5   Sales         3500 non-null   int64
#  6   Profit        3500 non-null   float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 191.5+ KB

# %% [markdown]
# 1. Order Date: Jumlah baris: 3500 Tipe data: object Deskripsi: Tanggal Pesanan
#
# 2. Product Name: Jumlah baris: 3500 Tipe data: object Deskripsi: Nama Produk
#
# 3. Category: Jumlah baris: 3500 Tipe data: object Deskripsi: Kategori Produk
#
# 4. Region: Jumlah baris: 3500 Tipe data: object Deskripsi: Wilayah Transaksi
#
# 5. Quantity: Jumlah baris: 3500 Tipe data: int64 Deskripsi: Jumlah Produk yang Dibeli
#
# 6. Sales: Jumlah baris: 3500 Tipe data: int64 Deskripsi: Total Nilai Penjualan
#
# 7. Profit: Jumlah baris: 3500 Tipe data: float64 Deskripsi: Keuntungan dari Setiap Transaksi

# %% [markdown]
# ### **Informasi Statistik Deskriptif**

# %%
df.describe(include='all')
# Out:
#         Order Date Product Name     Category Region     Quantity  \
# count         3500         3500         3500   3500  3500.000000
# unique        1051           10            3      4          NaN
# top     2023-08-12      Monitor  Electronics   West          NaN
# freq            11          364         1742    898          NaN
# mean           NaN          NaN          NaN    NaN     4.931714
# std            NaN          NaN          NaN    NaN     2.575895
# min            NaN          NaN          NaN    NaN     1.000000
# 25%            NaN          NaN          NaN    NaN     3.000000
# 50%            NaN          NaN          NaN    NaN     5.000000
# 75%            NaN          NaN          NaN    NaN     7.000000
# max            NaN          NaN          NaN    NaN     9.000000
#
#                Sales       Profit
# count    3500.000000  3500.000000
# unique           NaN          NaN
# top              NaN          NaN
# freq             NaN          NaN
# ...

# %% [markdown]
# 1. Count (Kelengkapan Data)
# Berdasarkan data, total baris transaksi adalah 3500. Maka dapat disimpulkan:
# * Seluruh kolom memiliki 3500 data (non-null)
# * Tidak terdapat missing values pada kolom Order Date, Product Name, Category, Region, Quantity, Sales, maupun Profit
#
# Kesimpulan :
# Dataset dalam kondisi lengkap tanpa nilai kosong, sehingga dapat langsung digunakan untuk analisis lanjutan tanpa proses imputasi data.
#
#
#
# ---
#
#
#
# 2. Mean vs Median (Distribusi Data)
#
# * Kolom Sales
#   * Mean = 3.047,97
#   * Median = 2.350,50
#
# Nilai rata-rata lebih besar dari median, menunjukkan adanya transaksi dengan nilai penjualan tinggi yang menarik rata-rata ke atas.
#
#
#
# ---
#
#
#
# * Kolom Quantity
#   * Mean = 4,93
#   * Median = 5,00
#
# Nilai mean dan median hampir sama, menunjukkan distribusi jumlah pembelian relatif seimbang dan tidak terlalu dipengaruhi oleh outlier.
#
# * Kolom Profit
#   * Mean = 527,05
#   * Median = 361,07
#
# Perbedaan antara mean dan median menunjukkan adanya beberapa transaksi dengan profit sangat tinggi yang meningkatkan nilai rata-rata.
#
# Kesimpulan :
# Data Sales dan Profit cenderung right-skewed (condong ke kanan) karena mean lebih besar dari median. Sementara Quantity relatif lebih stabil dan mendekati distribusi normal.
#
#
# ---
#
#
# 3. Min dan Max (Validasi Logika)
#
# * Sales
#   * Min = 51
#   * Max = 10.782
#
# * Quantity
#   * Min = 1
#   * Max = 9
#
# * Profit
#   * Min = 6,97
#   * Max = 2.946,93
#
# Kesimpulan:
#
# * Quantity maksimum 9 unit per transaksi masih tergolong wajar dalam konteks e-commerce retail.
#
# * Tidak terdapat nilai profit negatif, sehingga seluruh transaksi pada dataset ini menghasilkan keuntungan.
#
# * Rentang Sales yang cukup lebar menunjukkan variasi harga produk yang beragam.
#
#
#
# ---
#
#
# 4. Standar Deviasi (std) - Variabilitas Data
# * Sales
#   * Mean = 3.047,97
#   * Std = 2.440,21
#
# * Profit
#   * Mean = 527,05
#   * Std = 504,14
#
# Kesimpulan:
#
# * Pada kolom Sales, nilai standar deviasi yang cukup besar (sekitar 80% dari mean) menunjukkan bahwa nilai penjualan antar transaksi sangat bervariasi. Hal ini mengindikasikan adanya perbedaan harga produk atau jumlah pembelian yang signifikan di setiap transaksi.
#
# * Pada kolom Profit, nilai standar deviasi yang hampir mendekati rata-ratanya menunjukkan bahwa tingkat keuntungan antar transaksi juga cukup beragam. Meskipun seluruh transaksi menghasilkan profit positif, terdapat perbedaan yang cukup signifikan antara transaksi dengan keuntungan rendah dan keuntungan tinggi.
#
#
# * Pada kolom Quantity, nilai standar deviasi relatif kecil dibandingkan rata-ratanya, yang menunjukkan bahwa jumlah barang per transaksi tidak terlalu bervariasi.

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## **VERIFIKASI KUALITAS DATA**

# %% [markdown]
# ### **Data Type Check**

# %% [markdown]
# Kita akan mengecek tipe data dari setiap kolom apakah sudah sesuai atau tidak agar insight serta visualisasi yang dibuat menjadi akurat.
#
# Berdasarkan hasil pengecekan kolom Order Date masih bertipe data object padahal seharusnya bertipe datetime karena berisi informasi tanggal. Oleh karena itu, kolom ini perlu dikonversi. Selain itu, seluruh kolom lainnya sudah memiliki tipe data yang sesuai dengan karakteristik datanya.

# %%
df.dtypes
# Out:
# Order Date       object
# Product Name     object
# Category         object
# Region           object
# Quantity          int64
# Sales             int64
# Profit          float64
# dtype: object

# %% [markdown]
# ### **Incosistent Values**

# %% [markdown]
# Pada tahap ini, kita perlu mengecek kekonsistenan data pada setiap kolom, khususnya pada kolom bertipe kategorikal seperti Product Name, Category, dan Region. Pemeriksaan ini bertujuan untuk memastikan tidak terdapat perbedaan penulisan seperti huruf besar-kecil, spasi berlebih, atau variasi penamaan yang sebenarnya merujuk pada kategori yang sama.
#
# Hal ini penting dilakukan karena data yang tidak konsisten dapat menyebabkan duplikasi kategori secara tidak langsung dan memengaruhi hasil analisis maupun visualisasi yang dibuat.

# %% [markdown]
# 1. **Order Date**
#
# Pada kolom ini dapat dilihat, format tanggal pada kolom Order Date sudah seragam menggunakan format YYYY-MM-DD. Tidak ditemukan perbedaan format penulisan tanggal antar baris data.
#
# Namun, berdasarkan pengecekan tipe data, kolom ini masih bertipe object dan belum dalam format datetime. Oleh karena itu, perlu dilakukan konversi tipe data agar dapat digunakan untuk analisis berbasis waktu.

# %%
print(df['Order Date'].unique())
# Out:
# ['2024-12-31' '2022-11-27' '2022-05-11' ... '2022-09-20' '2023-10-06'
#  '2022-04-12']

# %% [markdown]
# penanganan Ketidakkonsistenan & Tipe data "Order Date" yang sebelumnya bertipe object menjadi datetime

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"], format="mixed")
df["Order Date"]
# Out:
# 0      2024-12-31
# 1      2022-11-27
# 2      2022-05-11
# 3      2024-03-16
# 4      2022-09-10
#           ...
# 3495   2023-02-15
# 3496   2022-09-18
# 3497   2022-04-12
# 3498   2022-01-18
# 3499   2024-11-01
# Name: Order Date, Length: 3500, dtype: datetime64[ns]

# %%
df.dtypes
# Out:
# Order Date      datetime64[ns]
# Product Name            object
# Category                object
# Region                  object
# Quantity                 int64
# Sales                    int64
# Profit                 float64
# dtype: object

# %% [markdown]
# 2. **Product Name**
#
# Berdasarkan hasil pengecekan tidak ditemukan perbedaan penulisan pada nama produk. Seluruh nama produk sudah konsisten tanpa adanya perbedaan huruf besar-kecil, spasi berlebih, maupun variasi penamaan lainnya.
#
# Dengan demikian, kolom Product Name tidak memiliki inconsistent values.

# %%
print(df['Product Name'].unique())
# Out:
# ['Printer' 'Mouse' 'Tablet' 'Camera' 'Headphones' 'Smartwatch' 'Monitor'
#  'Smartphone' 'Keyboard' 'Laptop']

# %% [markdown]
# 3. **Category**
#
# Berdasarkan hasil pengecekan, kategori yang terdapat pada kolom ini hanya terdiri dari beberapa nilai dan seluruhnya sudah konsisten dalam penulisan. Tidak ditemukan perbedaan huruf besar-kecil maupun variasi penamaan yang merujuk pada kategori yang sama.
#
# Dengan demikian, kolom Category tidak memiliki inconsistent values.

# %%
print(df['Category'].unique())
# Out:
# ['Office' 'Accessories' 'Electronics']

# %% [markdown]
# 4. **Region**
#
# Berdasarkan hasil pengecekan, seluruh wilayah pada kolom Region sudah memiliki penulisan yang konsisten. Tidak ditemukan perbedaan format maupun variasi nama wilayah yang merujuk pada kategori yang sama.
#
# Dengan demikian, kolom Region tidak memiliki inconsistent values.

# %%
print(df['Region'].unique())
# Out:
# ['North' 'East' 'South' 'West']

# %% [markdown]
# ### **Missing Values**

# %% [markdown]
# Pada tahap ini, dilakukan pengecekan untuk mengetahui jumlah data yang hilang (missing values) pada setiap kolom dalam dataset.
# Berdasarkan hasil pengecekan, seluruh kolom memiliki missing values sebesar 0%. Hal ini menunjukkan bahwa dataset sudah lengkap dan tidak memerlukan penanganan terhadap data yang hilang.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#               Null Ratio in %
# Order Date                0.0
# Product Name              0.0
# Category                  0.0
# Region                    0.0
# Quantity                  0.0
# Sales                     0.0
# Profit                    0.0

# %% [markdown]
# Terlihat pada dataset ini tidak ada missing values. Maka hal ini tidak perlu ditangani

# %% [markdown]
# ### **Duplicated Values**

# %% [markdown]
# Pada tahap ini dilakukan pengecekan data duplikat untuk memastikan tidak ada baris yang sama dalam dataset, sehingga hasil analisis tetap akurat dan bersih.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order Date, Product Name, Category, Region, Quantity, Sales, Profit]
# Index: []

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Terlihat pada dataset ini tidak ada duplikasi. Maka hal ini tidak perlu ditangani

# %% [markdown]
# Berdasarkan hasil pengecekan tidak ditemukan baris data yang terduplikasi pada dataset. Hal ini dapat dilihat dari output yang kosong, yang menunjukkan bahwa tidak ada baris dengan nilai yang sama persis pada seluruh kolom.
#
# Dengan demikian, dataset sudah bersih dari data duplikat dan dapat digunakan untuk proses analisis lebih lanjut tanpa perlu dilakukan penghapusan data.

# %% [markdown]
# ### **Outliers Values**

# %% [markdown]
# Outliers adalah nilai yang jauh berbeda dari nilai lainnya dalam dataset. Nilai Outlier bisa jauh lebih rendah atau lebih tinggi. Outlier bisa terjadi karena berbagai alasan seperti faktor kesalahan maupun kejadian lain yang tidak terduga.

# %% [markdown]
# Pada tahap ini, kita akan melihat nilai ekstrem (outliers) pada kolom yang bertipe data numerik. Hal ini dilakukan agar mendapatkan insight yang akurat sehingga dapat memperkuat analisis yang akan dilakukan.
#
# Akan tetapi, tidak semua kolom perlu ditangani. Kita tetap harus melihat dan memahami konteks dari setiap kolom yang ada pada dataset.
#
# Dan terlihat kolom:
#
# * Quantity
#
# Dengan persentase 0%
#
# * Sales
#
# Dengan persentase 1%
#
# * Profit
#
# Dengan persentase 5.26%

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom     Persentase Outliers
# Quantity             0.000000
# Sales                1.000000
# Profit               5.257143

# %% [markdown]
# 1. **Quantity**
#
# Memiliki persentase outlier sebesar 0%
#
# Karena tidak ditemukan outlier pada kolom Quantity (0%), maka tidak diperlukan penanganan khusus. Hal ini menunjukkan bahwa jumlah barang yang dibeli oleh pelanggan masih berada dalam rentang yang wajar dan tidak terdapat pembelian dalam jumlah yang ekstrem.
#
# Dengan demikian, data pada kolom Quantity tetap digunakan sepenuhnya dalam analisis karena sudah merepresentasikan kondisi transaksi yang normal tanpa adanya nilai yang menyimpang.

# %% [markdown]
# 2. **Sales**
#
# Memiliki persentase outlier sebesar 1%
#
# Berdasarkan hasil deteksi menggunakan metode IQR (Interquartile Range), ditemukan bahwa terdapat outlier pada kolom Sales sebesar 1% dari total data. Meskipun jumlahnya relatif kecil, nilai tersebut tetap termasuk dalam kategori outlier karena berada di luar batas bawah atau batas atas yang telah ditentukan.
#
# Sesuai dengan teori penanganan outlier yang digunakan, jika jumlah outlier kurang dari atau sama dengan 10% dari total data, maka data tersebut dapat dihapus. Oleh karena itu, dilakukan penghapusan terhadap data outlier pada kolom Sales.
#
# Penghapusan ini bertujuan untuk mengurangi pengaruh nilai penjualan yang terlalu ekstrem terhadap perhitungan statistik seperti rata-rata (mean), sehingga hasil analisis menjadi lebih stabil dan lebih merepresentasikan mayoritas transaksi yang terjadi.

# %%
Q1 = df['Sales'].quantile(0.25)
Q3 = df['Sales'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['Sales'] = df['Sales'].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# 3. **Profit**
#
# Berdasarkan hasil pengecekan, terdapat outlier pada kolom Profit sebesar 5,25% dari total data. Walaupun jumlahnya masih di bawah 10%, nilai profit yang terlalu tinggi atau terlalu rendah bisa memengaruhi perhitungan rata-rata dan membuat hasil analisis menjadi kurang stabil.
#
# Outlier pada Profit bisa terjadi karena adanya diskon besar, promosi, atau perbedaan keuntungan antar produk. Namun, jika dibiarkan begitu saja, nilai yang terlalu ekstrem bisa membuat rata-rata keuntungan terlihat tidak sesuai dengan kondisi mayoritas transaksi.
#
# Oleh karena itu, dilakukan penanganan menggunakan metode IQR (Interquartile Range). Metode ini bekerja dengan menentukan batas bawah dan batas atas berdasarkan sebaran data, sehingga kita bisa membedakan mana nilai yang masih wajar dan mana yang sudah terlalu ekstrem.

# %%
Q1 = df['Profit'].quantile(0.25)
Q3 = df['Profit'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['Profit'] = df['Profit'].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# 4. **Mengecek Kembali Nilai Ekstrem**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom     Persentase Outliers
# Quantity                  0.0
# Sales                     0.0
# Profit                    0.0

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Sales'])
plt.title('Boxplot of Sales')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# Setelah dilakukan penanganan outlier menggunakan metode IQR, boxplot menunjukkan bahwa tidak terdapat lagi nilai penjualan yang berada di luar batas bawah maupun batas atas. Artinya, nilai transaksi yang sebelumnya terlalu ekstrem telah dihapus sehingga distribusi data menjadi lebih stabil.
#
# Sebagian besar nilai Sales kini berada dalam rentang yang lebih terkendali, dan sebaran data terlihat lebih seimbang. Jarak antara kuartil pertama (Q1) dan kuartil ketiga (Q3) menjadi lebih representatif terhadap mayoritas transaksi.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Profit'])
plt.title('Boxplot of Profit')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# Setelah dilakukan penanganan menggunakan metode IQR, boxplot menunjukkan bahwa tidak lagi terdapat nilai yang berada di luar batas bawah maupun batas atas. Hal ini menandakan bahwa outlier pada kolom Profit telah berhasil ditangani.
#
# Sebelumnya terdapat 5,25% data yang termasuk outlier. Setelah proses penanganan dilakukan, sebaran data menjadi lebih stabil dan tidak ada lagi nilai ekstrem yang dapat memengaruhi perhitungan rata-rata.
#
# Median berada di tengah distribusi dan rentang antar kuartil (IQR) terlihat lebih terkontrol, sehingga data Profit kini lebih representatif terhadap mayoritas transaksi.

# %% [markdown]
# # **Construct Data**

# %% [markdown]
# 1. **Membuat Kolom Baru "Profit Status"**
#
# Kolom Profit_Status dibuat untuk mempermudah melihat apakah suatu transaksi menghasilkan keuntungan atau kerugian. Nilai profit yang awalnya berupa angka diubah menjadi kategori seperti Untung, Impas, dan Rugi agar lebih mudah dibaca dan dipahami.
#
# Dengan adanya kolom ini, kita tidak perlu melihat angka profit satu per satu untuk mengetahui kondisi transaksi. Kita bisa langsung melihat berapa banyak transaksi yang untung dan berapa yang rugi.

# %%
def categorize_profit(profit):
    if profit > 0:
        return 'Untung'
    elif profit < 0:
        return 'Rugi'
    else:
        return 'Break Even'

df['Profit Status'] = df['Profit'].apply(categorize_profit)

# %% [markdown]
# **Mengecek Kolom Baru**
#
# Dapat dilihat kolom baru yang kita buat "Profit Status" sudah terlihat.

# %%
df
# Out:
#      Order Date Product Name     Category Region  Quantity    Sales   Profit  \
# 0    2024-12-31      Printer       Office  North         4  3640.00   348.93
# 1    2022-11-27        Mouse  Accessories   East         7  1197.00   106.53
# 2    2022-05-11       Tablet  Electronics  South         5  5865.00   502.73
# 3    2024-03-16        Mouse  Accessories  South         2   786.00   202.87
# 4    2022-09-10        Mouse  Accessories   West         1   509.00   103.28
# ...         ...          ...          ...    ...       ...      ...      ...
# 3495 2023-02-15      Monitor  Accessories  North         4  4064.00   771.16
# 3496 2022-09-18      Monitor  Accessories   East         1  1117.00   119.89
# 3497 2022-04-12       Laptop  Electronics  South         4   260.00    66.02
# 3498 2022-01-18      Printer       Office  South         3   222.00    50.28
# 3499 2024-11-01   Smartwatch  Electronics   East         9  9768.25  1584.77
#
#      Profit Status
# 0           Untung
# ...

# %% [markdown]
# 1. **Membuat Kolom Baru "Profit Margin"**
#
# Kolom Profit_Margin dibuat untuk mengetahui seberapa besar keuntungan yang diperoleh dari setiap penjualan. Nilai ini menunjukkan persentase keuntungan dibandingkan dengan total penjualan (Sales).
#
# Dengan adanya Profit_Margin, kita tidak hanya melihat besar kecilnya profit dalam bentuk angka, tetapi juga bisa mengetahui apakah suatu transaksi memiliki keuntungan yang tinggi atau rendah secara proporsional.
#
# Kolom ini membantu dalam menganalisis tingkat profitabilitas secara lebih jelas dan mempermudah dalam membandingkan keuntungan antar transaksi.

# %%
df["Profit_Margin"] = (df["Profit"] / df["Sales"])

# %% [markdown]
# **Mengecek Kolom Baru**
#
# Dapat dilihat kolom baru yang kita buat "Profit Margin" sudah terlihat.

# %%
df
# Out:
#      Order Date Product Name     Category Region  Quantity    Sales   Profit  \
# 0    2024-12-31      Printer       Office  North         4  3640.00   348.93
# 1    2022-11-27        Mouse  Accessories   East         7  1197.00   106.53
# 2    2022-05-11       Tablet  Electronics  South         5  5865.00   502.73
# 3    2024-03-16        Mouse  Accessories  South         2   786.00   202.87
# 4    2022-09-10        Mouse  Accessories   West         1   509.00   103.28
# ...         ...          ...          ...    ...       ...      ...      ...
# 3495 2023-02-15      Monitor  Accessories  North         4  4064.00   771.16
# 3496 2022-09-18      Monitor  Accessories   East         1  1117.00   119.89
# 3497 2022-04-12       Laptop  Electronics  South         4   260.00    66.02
# 3498 2022-01-18      Printer       Office  South         3   222.00    50.28
# 3499 2024-11-01   Smartwatch  Electronics   East         9  9768.25  1584.77
#
#      Profit Status  Profit_Margin
# ...

# %% [markdown]
# Kolom Profit_Status dibuat untuk mempermudah melihat kondisi untung atau rugi secara kategori.
#
# Sedangkan Profit_Margin dibuat untuk mengetahui persentase keuntungan dari setiap transaksi agar analisis profitabilitas menjadi lebih mendalam.

# %% [markdown]
# # **Data Reduction**

# %% [markdown]
# Pada tahap data reduction, dilakukan pengecekan untuk melihat apakah ada kolom yang tidak diperlukan dalam analisis penjualan dan profit.
#
# Setelah dicek, semua kolom yang ada masih berhubungan dengan analisis yang dilakukan. Kolom seperti Order Date bisa digunakan untuk melihat tren waktu, Category dan Region bisa digunakan untuk perbandingan, sedangkan Quantity, Sales, dan Profit digunakan untuk menghitung penjualan dan keuntungan.
#
# Karena semua kolom masih bermanfaat, maka tidak dilakukan penghapusan data agar informasi tetap lengkap dan analisis bisa dilakukan dengan lebih menyeluruh.

# %% [markdown]
# # **Eksplorasi Data (EDA)**

# %% [markdown]
# ## **Comparison/Perbandingan**

# %% [markdown]
# Aktivitas : Membandingkan total penjualan (Sales) pada setiap wilayah (Region).
#
# Tujuan : Untuk mengetahui wilayah mana yang memberikan kontribusi penjualan terbesar serta membandingkan performa penjualan antar wilayah secara langsung.
#
# Visualisasi : Bar Chart (Grafik Batang).

# %%
penjualan_region = df.groupby("Region")["Sales"].sum()
penjualan_region
# Out:
# Region
# East     2675110
# North    2488773
# South    2659548
# West     2844450
# Name: Sales, dtype: int64

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    x=penjualan_region.index,
    y=penjualan_region.values,
    hue=penjualan_region.index,
    legend=False
)

plt.title("Total Penjualan per Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.show()

# %% [markdown]
# Grafik ini membandingkan total penjualan dari setiap wilayah.
#
# Wilayah West memiliki total penjualan paling tinggi dibanding wilayah lainnya. Ini berarti wilayah tersebut memberikan kontribusi terbesar terhadap pendapatan.
#
# Wilayah East dan South memiliki total penjualan yang hampir sama dan berada di posisi tengah.
#
# Sedangkan wilayah North memiliki total penjualan paling rendah dibanding wilayah lain, meskipun tetap memberikan kontribusi yang cukup besar.

# %% [markdown]
# ## **Composition/Komposisi**

# %% [markdown]
# Aktivitas: Melihat komposisi penjualan berdasarkan Category.
#
# Tujuan: Mengidentifikasi kategori dengan kontribusi penjualan terbesar dibandingkan kategori lainnya.
#
# Visualisasi: Pie Chart.

# %%
sales_by_category = df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
sales_by_category_top3 = sales_by_category.head(3)

plt.figure(figsize=(10, 8))
sales_by_category_top3.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Proporsi 3 Kategori Produk Teratas Berdasarkan Total Penjualan')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# Grafik ini menunjukkan persentase penjualan berdasarkan kategori produk.
#
# Kategori Electronics memberikan kontribusi terbesar, yaitu sekitar 49,9% dari total penjualan. Artinya, hampir setengah dari seluruh penjualan berasal dari produk elektronik.
#
# Di posisi kedua ada kategori Accessories, yang menyumbang sekitar 39,8% dari total penjualan.
#
# Sedangkan kategori Office memberikan kontribusi paling kecil, yaitu sekitar 10,3% dari total penjualan.

# %% [markdown]
# ## **Distribution/Distribusi**

# %% [markdown]
# Aktivitas : Menganalisis distribusi nilai transaksi pada kolom Sales.
#
# Tujuan : Untuk mengetahui pola penyebaran nilai transaksi, melihat apakah mayoritas transaksi bernilai kecil atau besar, serta mengidentifikasi adanya kecenderungan distribusi (skewness) pada data penjualan.
#
# Visualisasi : Histogram.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Sales'], bins=20, kde=True)
plt.title('Distribusi Penjualan (Sales)')
plt.xlabel('Sales')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Distribusi Sales tidak berbentuk normal karena tidak simetris. Grafik menunjukkan pola right-skewed (positively skewed), dimana sebagian besar transaksi berada pada nilai rendah dan hanya sedikit transaksi dengan nilai sangat tinggi.

# %% [markdown]
# ## **Relationship/Hubungan**

# %% [markdown]
# Aktivitas : Menganalisis hubungan antara nilai penjualan (Sales) dengan keuntungan (Profit).
#
# Tujuan : Untuk mengetahui apakah peningkatan nilai penjualan berbanding lurus dengan peningkatan profit, serta mengidentifikasi kemungkinan adanya transaksi dengan penjualan tinggi namun menghasilkan profit rendah atau bahkan kerugian.
#
# Visualisasi : Heatmap

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['Sales', 'Profit']].corr(),
            annot=True,
            cmap='coolwarm',
            fmt='.2f')
plt.title('Korelasi antara Sales dan Profit')
plt.show()

# %% [markdown]
# Heatmap digunakan untuk melihat hubungan antar variabel dalam bentuk korelasi. Pada visualisasi ini, warna merah menunjukkan hubungan positif, sedangkan warna biru menunjukkan hubungan negatif.
#
# Berdasarkan heatmap tersebut, nilai korelasi antara Sales dan Profit adalah 0,83.
#
# Nilai 0,83 menunjukkan bahwa Sales dan Profit memiliki hubungan positif yang kuat. Artinya, ketika penjualan meningkat, keuntungan juga cenderung meningkat.
#
# Warna merah pada bagian diagonal menunjukkan nilai 1,00 karena variabel dibandingkan dengan dirinya sendiri. Sementara itu, nilai 0,83 antara Sales dan Profit menunjukkan hubungan yang kuat dan searah.

# %% [markdown]
# # **Menyimpan Dataset (Bersih)**

# %%
df.to_csv('/content/drive/MyDrive/ecommerce_sales_data_bersih (2).csv', index=False)
